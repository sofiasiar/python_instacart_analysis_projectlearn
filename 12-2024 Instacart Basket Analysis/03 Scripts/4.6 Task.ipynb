# %% [markdown]
# # Combining & Exporting Data Task

# %% [markdown]
# # This script contains task 4.6

# %% [markdown]
# # Importing Libraries and creating dataframes

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
orders_products_combined = pd.read_csv(r'C:\Users\sosia\12-2024 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.csv', index_col = False)

# %%
df_prods = pd.read_csv(r'C:\Users\sosia\12-2024 Instacart Basket Analysis\02 Data\Prepared Data\products_checked.csv', index_col = False)

# %%
path= r"C:\Users\sosia\12-2024 Instacart Basket Analysis"

# %% [markdown]
# # 03 Check the ouput

# %%
# Check the ouput
orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           0   2539329        1    prior             1
# 2             2           0   2539329        1    prior             1
# 3             3           0   2539329        1    prior             1
# 4             4           0   2539329        1    prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
orders_products_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    1           0   2539329        1    prior             1
# 2                    2           0   2539329        1    prior             1
# 3                    3           0   2539329        1    prior             1
# 4                    4           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 19840818      19840818     2092297   1646829   125801    prior             4
# 19840819      19840819     2092298   1542841   125801    prior             5
# 19840820      19840820     2092298   1542841   125801    prior             5
# 19840821      19840821     2092298   1542841   125801    prior             5
# 19840822      19840822     2092298   1542841   125801    prior             5
#
# ...

# %% [markdown]
# # 04 Check the shape

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
orders_products_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    1           0   2539329        1    prior             1
# 2                    2           0   2539329        1    prior             1
# 3                    3           0   2539329        1    prior             1
# 4                    4           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 19840818      19840818     2092297   1646829   125801    prior             4
# 19840819      19840819     2092298   1542841   125801    prior             5
# 19840820      19840820     2092298   1542841   125801    prior             5
# 19840821      19840821     2092298   1542841   125801    prior             5
# 19840822      19840822     2092298   1542841   125801    prior             5
#
# ...

# %%
orders_products_combined.shape
# Out:
# (19840823, 13)

# %%
orders_products_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                    0           0   2539329        1    prior             1
# 1                    1           0   2539329        1    prior             1
# 2                    2           0   2539329        1    prior             1
# 3                    3           0   2539329        1    prior             1
# 4                    4           0   2539329        1    prior             1
# ...                ...         ...       ...      ...      ...           ...
# 19840818      19840818     2092297   1646829   125801    prior             4
# 19840819      19840819     2092298   1542841   125801    prior             5
# 19840820      19840820     2092298   1542841   125801    prior             5
# 19840821      19840821     2092298   1542841   125801    prior             5
# 19840822      19840822     2092298   1542841   125801    prior             5
#
# ...

# %% [markdown]
# # 05 Combine dataframes

# %%
# merge with key product_id,

# %%
df_merged_large = orders_products_combined.merge(df_prods, on = 'product_id')

# %% [markdown]
# # 06 Confirm results

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             0   2539329        1    prior             1
# 2             2             0   2539329        1    prior             1
# 3             3             0   2539329        1    prior             1
# 4             4             0   2539329        1    prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     NaN         196
# 1          2                  8                     NaN       14084
# 2          2                  8                     NaN       12427
# 3          2                  8                     NaN       26088
# 4          2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge  Unnamed: 0_y  \
# 0                  1          0   both           195
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both    19822744
# Name: count, dtype: int64

# %% [markdown]
# # 07 Export as pkl

# %%
# Exporting as pkl due to size
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
