# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path= r"C:\Users\sosia\12-2024 Instacart Basket Analysis"

# %%
df = pd.read_pickle(r'C:\Users\sosia\12-2024 Instacart Basket Analysis\02 Data\Prepared Data\df47_busy.pkl')

# %%
ords_prods_merge = df

# %%
ords_prods_merge
# Out:
#         Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0                  0             0   2539329        1    prior             1
# 1                  1             0   2539329        1    prior             1
# 2                  2             0   2539329        1    prior             1
# 3                  3             0   2539329        1    prior             1
# 4                  4             0   2539329        1    prior             1
# ...              ...           ...       ...      ...      ...           ...
# 999995       1000935        106983   2789027     6474    prior             2
# 999996       1000936        106983   2789027     6474    prior             2
# 999997       1000937        106983   2789027     6474    prior             2
# 999998       1000938        106983   2789027     6474    prior             2
# 999999       1000939        106983   2789027     6474    prior             2
#
# ...

# %%
df = ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             0   2539329        1    prior             1
# 2             2             0   2539329        1    prior             1
# 3             3             0   2539329        1    prior             1
# 4             4             0   2539329        1    prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          2                  8                     NaN       14084  ...
# 2          2                  8                     NaN       12427  ...
# 3          2                  8                     NaN       26088  ...
# 4          2                  8                     NaN       26405  ...
#
#    reordered  _merge Unnamed: 0_y                             product_name  \
# ...

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# # Aggregating Data with transform()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\sosia\AppData\Local\Temp\ipykernel_41772\1681540670.py:1: FutureWarning: The provided callable <function max at 0x000001C33ED28400> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             0   2539329        1    prior             1
# 2             2             0   2539329        1    prior             1
# 3             3             0   2539329        1    prior             1
# 4             4             0   2539329        1    prior             1
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# 0          2                  8                     NaN         196  ...
# 1          2                  8                     NaN       14084  ...
# 2          2                  8                     NaN       12427  ...
# 3          2                  8                     NaN       26088  ...
# 4          2                  8                     NaN       26405  ...
#
#    _merge  Unnamed: 0_y                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0             0   2539329        1    prior             1
# 1              1             0   2539329        1    prior             1
# 2              2             0   2539329        1    prior             1
# 3              3             0   2539329        1    prior             1
# 4              4             0   2539329        1    prior             1
# ..           ...           ...       ...      ...      ...           ...
# 95            95            14    738281        2    prior             4
# 96            96            15   1673511        2    prior             5
# 97            97            15   1673511        2    prior             5
# 98            98            15   1673511        2    prior             5
# 99            99            15   1673511        2    prior             5
#
#     order_dow  order_hour_of_day  days_since_prior_order  product_id  ...  \
# ...

# %%
pd.options.display.max_rows = None

# %% [markdown]
# # Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    482391
# Loyal customer      322011
# New customer        195598
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
# 07 Export as pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge1.pkl'))
